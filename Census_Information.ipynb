# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import sklearn
import scipy
from sklearn import ensemble
from sklearn.metrics import mean_squared_error

# %%
census2 = pd.read_csv('/Users/cappsjr/Downloads/DEC_10_SF1_GCTP3.CY10/DEC_10_SF1_GCTP3.CY10_with_ann.csv')
census2.head(10)
# Out:
#            GEO.id GEO.id2        GEO.display-label    GCT_STUB.target-geo-id  \
# 0              Id     Id2                Geography             Target Geo Id
# 1  0500000US53033   53033  King County, Washington            0500000US53033
# 2  0500000US53033   53033  King County, Washington       0600000US5303391056
# 3  0500000US53033   53033  King County, Washington  0700000US530339105603180
# 4  0500000US53033   53033  King County, Washington  0700000US530339105606330
# 5  0500000US53033   53033  King County, Washington  0700000US530339105622045
# 6  0500000US53033   53033  King County, Washington  0700000US530339105635415
# 7  0500000US53033   53033  King County, Washington  0700000US530339105637345
# 8  0500000US53033   53033  King County, Washington  0700000US530339105637567
# 9  0500000US53033   53033  King County, Washington  0700000US530339105643150
#
#   GCT_STUB.target-geo-id2                             GCT_STUB.display-label  \
# ...

# %%
census2['GCT_STUB.display-label'].unique()
# Out:
# array(['Geographic area', 'King County',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Auburn city (part)',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Black Diamond city',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Enumclaw city (part)',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Kent city (part)',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Lake Holm CDP (part)',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Lake Morton-Berrydale CDP (part)',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Maple Valley city (part)',
#        'King County - COUNTY SUBDIVISION AND PLACE - Enumclaw Plateau CCD - Ravensdale CDP',
# ...

# %%
location = census2['GCT_STUB.display-label'] == 'King County - PLACE - Algona city'
census2[location]
# Out:
#              GEO.id GEO.id2        GEO.display-label GCT_STUB.target-geo-id  \
# 106  0500000US53033   53033  King County, Washington    1590000US5303301290
#
#     GCT_STUB.target-geo-id2             GCT_STUB.display-label  \
# 106              5303301290  King County - PLACE - Algona city
#
#     GCT_STUB.display-label.1  HD01 SUBHD02010101 SUBHD02010102 SUBHD02010103  \
# 106              Algona city  3014          67.1           3.3           1.7
#
#     SUBHD02010104 SUBHD02010105 SUBHD02010106 SUBHD020102 SUBHD0202 SUBHD0203
# 106          11.7           2.0           7.5         6.8      15.9      61.1

# %%
census2 = census2.drop(census2.index[2:106])

# %%
census2 = census2.drop('GCT_STUB.display-label', axis=1)

# %%
census2.head(5)
# Out:
#              GEO.id GEO.id2        GEO.display-label GCT_STUB.target-geo-id  \
# 0                Id     Id2                Geography          Target Geo Id
# 1    0500000US53033   53033  King County, Washington         0500000US53033
# 106  0500000US53033   53033  King County, Washington    1590000US5303301290
# 107  0500000US53033   53033  King County, Washington    1590000US5303301920
# 108  0500000US53033   53033  King County, Washington    1590000US5303303180
#
#     GCT_STUB.target-geo-id2 GCT_STUB.display-label.1              HD01  \
# 0            Target Geo Id2          Geographic area  Total population
# 1                     53033              King County           1931249
# 106              5303301290              Algona city              3014
# 107              5303301920            Ames Lake CDP              1486
# 108              5303303180       Auburn city (part)             62761
#
#                                          SUBHD02010101  \
# ...

# %%
header = census2.iloc[0]

# %%
census2 = census2[1:]

# %%
census2 = census2.rename(columns = header)

# %%
census2.columns
# Out:
# Index(['Id', 'Id2', 'Geography', 'Target Geo Id', 'Target Geo Id2',
#        'Geographic area', 'Total population',
#        'Percent of total population - Race - One Race - White',
#        'Percent of total population - Race - One Race - Black or African American',
#        'Percent of total population - Race - One Race - American Indian and Alaska Native',
#        'Percent of total population - Race - One Race - Asian',
#        'Percent of total population - Race - One Race - Native Hawaiian and Other Pacific Islander',
#        'Percent of total population - Race - One Race - Some Other Race',
#        'Percent of total population - Race - Two or More Races',
#        'Percent of total population - Hispanic or Latino (of any race)',
#        'Percent of total population - White Alone, not Hispanic or Latino'],
#       dtype='object')

# %%
census2.dtypes
# Out:
# Id                                                                                            object
# Id2                                                                                           object
# Geography                                                                                     object
# Target Geo Id                                                                                 object
# Target Geo Id2                                                                                object
# Geographic area                                                                               object
# Total population                                                                              object
# Percent of total population - Race - One Race - White                                         object
# Percent of total population - Race - One Race - Black or African American                     object
# ...

# %%
pop_perc = ['Total population', 
            'Percent of total population - Race - One Race - White',
           'Percent of total population - Race - One Race - Black or African American', 
           'Percent of total population - Race - One Race - American Indian and Alaska Native',
           'Percent of total population - Race - One Race - Asian',
           'Percent of total population - Race - One Race - Native Hawaiian and Other Pacific Islander',
           'Percent of total population - Race - One Race - Some Other Race',
           'Percent of total population - Race - Two or More Races',
           'Percent of total population - Hispanic or Latino (of any race)',
           'Percent of total population - White Alone, not Hispanic or Latino']

for item in pop_perc:
    census2[item] = pd.to_numeric(census2[item])

# %%
census2['Percent Minority'] = 100 - census2['Percent of total population - White Alone, not Hispanic or Latino']
census2.head()
# Out:
#                  Id    Id2                Geography        Target Geo Id  \
# 1    0500000US53033  53033  King County, Washington       0500000US53033
# 106  0500000US53033  53033  King County, Washington  1590000US5303301290
# 107  0500000US53033  53033  King County, Washington  1590000US5303301920
# 108  0500000US53033  53033  King County, Washington  1590000US5303303180
# 109  0500000US53033  53033  King County, Washington  1590000US5303304300
#
#     Target Geo Id2     Geographic area  Total population  \
# 1            53033         King County           1931249
# 106     5303301290         Algona city              3014
# 107     5303301920       Ames Lake CDP              1486
# 108     5303303180  Auburn city (part)             62761
# 109     5303304300          Baring CDP               220
#
#      Percent of total population - Race - One Race - White  \
# 1                                                 68.7
# 106                                               67.1
# ...

# %%
top_minority_comm = census2.sort_values('Percent Minority', ascending=False)
top_minority_comm.head(10)
# Out:
#                  Id    Id2                Geography        Target Geo Id  \
# 115  0500000US53033  53033  King County, Washington  1590000US5303308552
# 168  0500000US53033  53033  King County, Washington  1590000US5303372625
# 114  0500000US53033  53033  King County, Washington  1590000US5303307397
# 161  0500000US53033  53033  King County, Washington  1590000US5303362288
# 171  0500000US53033  53033  King County, Washington  1590000US5303378225
# 159  0500000US53033  53033  King County, Washington  1590000US5303358865
# 157  0500000US53033  53033  King County, Washington  1590000US5303357745
# 135  0500000US53033  53033  King County, Washington  1590000US5303335415
# 129  0500000US53033  53033  King County, Washington  1590000US5303323515
# 124  0500000US53033  53033  King County, Washington  1590000US5303319515
#
#     Target Geo Id2         Geographic area  Total population  \
# 115     5303308552    Bryn Mawr-Skyway CDP             15645
# ...

# %%
wm = census2.sort_values('Percent of total population - White Alone, not Hispanic or Latino', ascending=False)
wm.head(10)
# Out:
#                  Id    Id2                Geography        Target Geo Id  \
# 110  0500000US53033  53033  King County, Washington  1590000US5303304895
# 165  0500000US53033  53033  King County, Washington  1590000US5303364855
# 167  0500000US53033  53033  King County, Washington  1590000US5303370315
# 172  0500000US53033  53033  King County, Washington  1590000US5303378780
# 155  0500000US53033  53033  King County, Washington  1590000US5303357395
# 150  0500000US53033  53033  King County, Washington  1590000US5303346215
# 158  0500000US53033  53033  King County, Washington  1590000US5303358742
# 143  0500000US53033  53033  King County, Washington  1590000US5303337538
# 170  0500000US53033  53033  King County, Washington  1590000US5303374305
# 130  0500000US53033  53033  King County, Washington  1590000US5303331495
#
#     Target Geo Id2             Geographic area  Total population  \
# 110     5303304895     Beaux Arts Village town               299
# ...

# %%
wm[wm['Total population'] > 5000].head(10)
# Out:
#                  Id    Id2                Geography        Target Geo Id  \
# 170  0500000US53033  53033  King County, Washington  1590000US5303374305
# 130  0500000US53033  53033  King County, Washington  1590000US5303331495
# 126  0500000US53033  53033  King County, Washington  1590000US5303322045
# 153  0500000US53033  53033  King County, Washington  1590000US5303349485
# 119  0500000US53033  53033  King County, Washington  1590000US5303314940
# 122  0500000US53033  53033  King County, Washington  1590000US5303319035
# 144  0500000US53033  53033  King County, Washington  1590000US5303337567
# 152  0500000US53033  53033  King County, Washington  1590000US5303349415
# 125  0500000US53033  53033  King County, Washington  1590000US5303319857
# 146  0500000US53033  53033  King County, Washington  1590000US5303343150
#
#     Target Geo Id2            Geographic area  Total population  \
# 170     5303374305                 Vashon CDP             10624
# ...
